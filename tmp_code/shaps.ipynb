# %%
"""
MOVE BACK ONE DIRECTORY BEFORE RUNNING
REPOPULATES TMP FOLDER
TAKES A LONG TIME
"""

import os,re
import json
import numpy as np
import pandas as pd
import pickle
import datetime
import matplotlib.pyplot as plt

from dataset import dataset

import xgboost as xgb
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import confusion_matrix, classification_report

import shap
from matplotlib.pyplot import figure

# %%
description, df = dataset()

# %%
model_categories = ['AircraftCategory', 'AmateurBuilt', 'NumberOfEngines', 'WeatherCondition', 'BroadPhaseOfFlight']

# %%
def dummy_vars(df, model_categories):
    dumb_cats = []
    for i in model_categories:
        if df[i].dtype == 'object':
            dumb = pd.get_dummies(df[i].replace('','Missing')).drop(['Missing'], axis=1)
            dumb.columns = [i+'_'+j for j in dumb.columns]
            dumb_cats.append(dumb)
        else:
            dumb_cats.append(pd.to_numeric(pd.Series(df[i].rename(i)), errors='coerce'))
    return dumb_cats

def model_dataset(df_, model_categories, over_sample=True):
    df = df_.copy()
    year_data = pd.DataFrame(data = [i.year for i in df.index], columns=['year'], index=df.index)
    
    dummies = dummy_vars(df, model_categories)
    dummies.append(year_data.fillna(year_data['year'].mean()))
    
    df_model = pd.concat(dummies, axis=1)
    
    df_target = (df[['TotalFatalInjuries','TotalSeriousInjuries']]>=1).max(axis=1)

    June_Mask = [i[:2]=='06' for i in df['EventDate']]

    x_train = df_model[np.logical_not(June_Mask)]
    y_train = df_target[np.logical_not(June_Mask)]
    x_test = df_model[June_Mask]
    y_test = df_target[June_Mask]
    
    if over_sample:
        oversample = RandomOverSampler(sampling_strategy='minority')
        x_over, y_over = oversample.fit_resample(x_train,y_train)
    
        return x_over, y_over, x_test, y_test
    
    else:
        return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = model_dataset(df, model_categories, over_sample=True)
dtrain = xgb.DMatrix(x_train, y_train)
dtest = xgb.DMatrix(x_test,y_test)

num_round = 160
param = {'max_depth': 6, 
         'eta': .03,
         'objective': 'binary:logistic'}
param['nthread'] = 4
param['eval_metric'] = 'auc'
evallist = [(dtest, 'eval'), (dtrain, 'train')]

bst = xgb.train(param, dtrain, num_round, evallist)
# Out:
# [0]	eval-auc:0.73834	train-auc:0.75184
# [1]	eval-auc:0.74618	train-auc:0.76050
# [2]	eval-auc:0.74699	train-auc:0.76094
# [3]	eval-auc:0.74730	train-auc:0.76102
# [4]	eval-auc:0.74810	train-auc:0.76140
# [5]	eval-auc:0.74814	train-auc:0.76141
# [6]	eval-auc:0.74834	train-auc:0.76135
# [7]	eval-auc:0.74813	train-auc:0.76133
# [8]	eval-auc:0.75121	train-auc:0.76311
# [9]	eval-auc:0.75133	train-auc:0.76326
# [10]	eval-auc:0.75243	train-auc:0.76387
# [11]	eval-auc:0.75214	train-auc:0.76395
# [12]	eval-auc:0.75174	train-auc:0.76399
# [13]	eval-auc:0.75156	train-auc:0.76392
# [14]	eval-auc:0.75225	train-auc:0.76426
# [15]	eval-auc:0.75377	train-auc:0.76584
# [16]	eval-auc:0.75520	train-auc:0.77023
# [17]	eval-auc:0.75540	train-auc:0.77039
# [18]	eval-auc:0.75550	train-auc:0.77048
# [19]	eval-auc:0.75549	train-auc:0.77051
# [20]	eval-auc:0.75539	train-auc:0.77035
# [21]	eval-auc:0.75552	train-auc:0.77041
# [22]	eval-auc:0.75553	train-auc:0.77067
# [23]	eval-auc:0.75669	train-auc:0.77150
# [24]	eval-auc:0.75682	train-auc:0.77148
# [25]	eval-auc:0.75693	train-auc:0.77146
# [26]	eval-auc:0.75703	train-auc:0.77153
# [27]	eval-auc:0.75702	train-auc:0.77158
# [28]	eval-auc:0.75724	train-auc:0.77169
# [29]	eval-auc:0.75686	train-auc:0.77160
# [30]	eval-auc:0.75700	train-auc:0.77166
# [31]	eval-auc:0.75727	train-auc:0.77181
# [32]	eval-auc:0.75728	train-auc:0.77182
# [33]	eval-auc:0.75728	train-auc:0.77185
# [34]	eval-auc:0.75741	train-auc:0.77189
# [35]	eval-auc:0.75748	train-auc:0.77194
# [36]	eval-auc:0.75744	train-auc:0.77192
# [37]	eval-auc:0.75769	train-auc:0.77209
# [38]	eval-auc:0.75762	train-auc:0.77212
# [39]	eval-auc:0.75764	train-auc:0.77217
# [40]	eval-auc:0.75765	train-auc:0.77219
# [41]	eval-auc:0.75755	train-auc:0.77218
# [42]	eval-auc:0.75763	train-auc:0.77220
# [43]	eval-auc:0.75757	train-auc:0.77223
# [44]	eval-auc:0.75760	train-auc:0.77235
# [45]	eval-auc:0.75746	train-auc:0.77247
# [46]	eval-auc:0.75752	train-auc:0.77254
# [47]	eval-auc:0.75764	train-auc:0.77269
# [48]	eval-auc:0.75780	train-auc:0.77270
# [49]	eval-auc:0.75784	train-auc:0.77287
# [50]	eval-auc:0.75788	train-auc:0.77290
# [51]	eval-auc:0.75752	train-auc:0.77302
# [52]	eval-auc:0.75744	train-auc:0.77316
# [53]	eval-auc:0.75740	train-auc:0.77316
# [54]	eval-auc:0.75745	train-auc:0.77317
# [55]	eval-auc:0.75737	train-auc:0.77322
# [56]	eval-auc:0.75723	train-auc:0.77329
# [57]	eval-auc:0.75724	train-auc:0.77329
# [58]	eval-auc:0.75737	train-auc:0.77336
# [59]	eval-auc:0.75745	train-auc:0.77335
# [60]	eval-auc:0.75802	train-auc:0.77399
# [61]	eval-auc:0.75814	train-auc:0.77399
# [62]	eval-auc:0.75823	train-auc:0.77411
# [63]	eval-auc:0.75840	train-auc:0.77453
# [64]	eval-auc:0.75845	train-auc:0.77452
# [65]	eval-auc:0.75868	train-auc:0.77499
# [66]	eval-auc:0.75870	train-auc:0.77499
# [67]	eval-auc:0.75892	train-auc:0.77516
# [68]	eval-auc:0.75897	train-auc:0.77518
# [69]	eval-auc:0.75897	train-auc:0.77524
# [70]	eval-auc:0.75906	train-auc:0.77529
# [71]	eval-auc:0.75903	train-auc:0.77532
# [72]	eval-auc:0.75901	train-auc:0.77551
# [73]	eval-auc:0.75903	train-auc:0.77553
# [74]	eval-auc:0.75944	train-auc:0.77568
# [75]	eval-auc:0.75958	train-auc:0.77569
# [76]	eval-auc:0.75959	train-auc:0.77565
# [77]	eval-auc:0.75971	train-auc:0.77573
# [78]	eval-auc:0.75946	train-auc:0.77577
# [79]	eval-auc:0.75950	train-auc:0.77580
# [80]	eval-auc:0.75970	train-auc:0.77581
# [81]	eval-auc:0.75968	train-auc:0.77584
# [82]	eval-auc:0.75971	train-auc:0.77588
# [83]	eval-auc:0.75976	train-auc:0.77590
# [84]	eval-auc:0.75960	train-auc:0.77599
# [85]	eval-auc:0.75950	train-auc:0.77590
# [86]	eval-auc:0.75949	train-auc:0.77591
# [87]	eval-auc:0.75948	train-auc:0.77592
# [88]	eval-auc:0.75939	train-auc:0.77587
# [89]	eval-auc:0.75943	train-auc:0.77589
# [90]	eval-auc:0.75999	train-auc:0.77630
# [91]	eval-auc:0.76013	train-auc:0.77648
# [92]	eval-auc:0.76021	train-auc:0.77653
# [93]	eval-auc:0.76018	train-auc:0.77652
# [94]	eval-auc:0.76057	train-auc:0.77698
# [95]	eval-auc:0.76063	train-auc:0.77702
# [96]	eval-auc:0.76074	train-auc:0.77705
# [97]	eval-auc:0.76082	train-auc:0.77704
# [98]	eval-auc:0.76071	train-auc:0.77710
# [99]	eval-auc:0.76068	train-auc:0.77716
# [100]	eval-auc:0.76091	train-auc:0.77725
# [101]	eval-auc:0.76107	train-auc:0.77731
# [102]	eval-auc:0.76103	train-auc:0.77732
# [103]	eval-auc:0.76131	train-auc:0.77773
# [104]	eval-auc:0.76127	train-auc:0.77789
# [105]	eval-auc:0.76131	train-auc:0.77793
# [106]	eval-auc:0.76157	train-auc:0.77799
# [107]	eval-auc:0.76159	train-auc:0.77801
# [108]	eval-auc:0.76143	train-auc:0.77812
# [109]	eval-auc:0.76130	train-auc:0.77819
# [110]	eval-auc:0.76134	train-auc:0.77820
# [111]	eval-auc:0.76135	train-auc:0.77827
# [112]	eval-auc:0.76145	train-auc:0.77838
# [113]	eval-auc:0.76159	train-auc:0.77848
# [114]	eval-auc:0.76152	train-auc:0.77850
# [115]	eval-auc:0.76125	train-auc:0.77853
# [116]	eval-auc:0.76130	train-auc:0.77858
# [117]	eval-auc:0.76143	train-auc:0.77863
# [118]	eval-auc:0.76155	train-auc:0.77874
# [119]	eval-auc:0.76145	train-auc:0.77886
# [120]	eval-auc:0.76158	train-auc:0.77892
# [121]	eval-auc:0.76144	train-auc:0.77907
# [122]	eval-auc:0.76157	train-auc:0.77915
# [123]	eval-auc:0.76170	train-auc:0.77919
# [124]	eval-auc:0.76189	train-auc:0.77938
# [125]	eval-auc:0.76197	train-auc:0.77959
# [126]	eval-auc:0.76202	train-auc:0.77964
# [127]	eval-auc:0.76206	train-auc:0.77973
# [128]	eval-auc:0.76215	train-auc:0.77973
# [129]	eval-auc:0.76209	train-auc:0.77982
# [130]	eval-auc:0.76214	train-auc:0.77985
# [131]	eval-auc:0.76219	train-auc:0.77995
# [132]	eval-auc:0.76219	train-auc:0.77997
# [133]	eval-auc:0.76205	train-auc:0.78001
# [134]	eval-auc:0.76204	train-auc:0.78002
# [135]	eval-auc:0.76205	train-auc:0.78004
# [136]	eval-auc:0.76212	train-auc:0.78010
# [137]	eval-auc:0.76208	train-auc:0.78012
# [138]	eval-auc:0.76217	train-auc:0.78020
# [139]	eval-auc:0.76219	train-auc:0.78024
# [140]	eval-auc:0.76217	train-auc:0.78026
# [141]	eval-auc:0.76206	train-auc:0.78028
# [142]	eval-auc:0.76208	train-auc:0.78038
# [143]	eval-auc:0.76205	train-auc:0.78040
# [144]	eval-auc:0.76212	train-auc:0.78043
# [145]	eval-auc:0.76216	train-auc:0.78048
# [146]	eval-auc:0.76224	train-auc:0.78054
# [147]	eval-auc:0.76227	train-auc:0.78065
# [148]	eval-auc:0.76232	train-auc:0.78070
# [149]	eval-auc:0.76229	train-auc:0.78072
# [150]	eval-auc:0.76230	train-auc:0.78074
# [151]	eval-auc:0.76234	train-auc:0.78075
# [152]	eval-auc:0.76245	train-auc:0.78080
# [153]	eval-auc:0.76246	train-auc:0.78083
# [154]	eval-auc:0.76248	train-auc:0.78086
# [155]	eval-auc:0.76249	train-auc:0.78083
# [156]	eval-auc:0.76246	train-auc:0.78087
# [157]	eval-auc:0.76244	train-auc:0.78088
# [158]	eval-auc:0.76265	train-auc:0.78103
# [159]	eval-auc:0.76288	train-auc:0.78132

# %%
pickle.dump(bst, open("../tmp/bst.pkl", "wb"))
explainer = shap.Explainer(bst)
shap_values = explainer(x_test)

pickle.dump(shap_values, open("../tmp/shap_values.pkl", "wb"))
# visualize the first prediction's explanation
pickle.dump(x_test, open("../tmp/x_test_for_shaps.pkl", "wb"))

yhat = bst.predict(dtest)>.5
confusion = [confusion_matrix(y_test, yhat),pd.DataFrame.from_dict(classification_report(y_test, yhat, output_dict=True))]
pickle.dump(confusion,open("../tmp/confusion.pkl", "wb"))
